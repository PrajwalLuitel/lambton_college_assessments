# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

from sklearn.cluster import KMeans

#reading countries list
data = pd.read_csv('iris.csv')

#selecting data to plot
x = data.iloc[:, 1:4]

y = data.iloc[:, 4:5]

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.7, random_state=0)

print (X_test)
#gaussian naive basyan
gnb = GaussianNB()
model = gnb.fit(X_train.values, y_train.values.ravel())
y_pred = model.predict(X_test.values)
print(f"GaussianNB: Number of mislabeled points out of a total { X_test.shape[0] } points : {(y_test.values.ravel() != y_pred).sum()}" )

print(model.predict(np.array([[3.2,5.9,2.3]])))

#decussion tree
from sklearn import tree
clf = tree.DecisionTreeClassifier()
model = clf.fit(X_train.values, y_train.values.ravel())
y_pred = model.predict(X_test.values)
print(f"DecisionTreeClassifier: Number of mislabeled points out of a total { X_test.shape[0] } points : {(y_test.values.ravel() != y_pred).sum()}" )
print(model.predict(np.array([[3.2,5.9,2.3]])))
# Out:
#      sepal.width  petal.length  petal.width
# 114          2.8           5.1          2.4
# 62           2.2           4.0          1.0
# 33           4.2           1.4          0.2
# 107          2.9           6.3          1.8
# 7            3.4           1.5          0.2
# ..           ...           ...          ...
# 38           3.0           1.3          0.2
# 5            3.9           1.7          0.4
# 53           2.3           4.0          1.3
# 143          3.2           5.9          2.3
# 105          3.0           6.6          2.1
#
# [105 rows x 3 columns]
# GaussianNB: Number of mislabeled points out of a total 105 points : 6
# ['Virginica']
# DecisionTreeClassifier: Number of mislabeled points out of a total 105 points : 5
# ['Virginica']

# %%
#selecting data to plot
x = data.iloc[:, 1:4]

y = data.iloc[:, 4:5]

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

print (X_test)
#gaussian naive basyan
gnb = GaussianNB()
model = gnb.fit(X_train.values, y_train.values.ravel())
y_pred = model.predict(X_test.values)
print(f"GaussianNB: Number of mislabeled points out of a total { X_test.shape[0] } points : {(y_test.values.ravel() != y_pred).sum()}" )

print(model.predict(np.array([[3.2,5.9,2.3]])))

#decussion tree
from sklearn import tree
clf = tree.DecisionTreeClassifier()
model = clf.fit(X_train.values, y_train.values.ravel())
y_pred = model.predict(X_test.values)
print(f"DecisionTreeClassifier: Number of mislabeled points out of a total { X_test.shape[0] } points : {(y_test.values.ravel() != y_pred).sum()}" )
print(model.predict(np.array([[3.2,5.9,2.3]])))
# Out:
#      sepal.width  petal.length  petal.width
# 114          2.8           5.1          2.4
# 62           2.2           4.0          1.0
# 33           4.2           1.4          0.2
# 107          2.9           6.3          1.8
# 7            3.4           1.5          0.2
# 100          3.3           6.0          2.5
# 40           3.5           1.3          0.3
# 86           3.1           4.7          1.5
# 76           2.8           4.8          1.4
# 71           2.8           4.0          1.3
# 134          2.6           5.6          1.4
# 51           3.2           4.5          1.5
# 73           2.8           4.7          1.2
# 54           2.8           4.6          1.5
# 63           2.9           4.7          1.4
# 37           3.6           1.4          0.1
# 78           2.9           4.5          1.5
# 90           2.6           4.4          1.2
# 45           3.0           1.4          0.3
# 16           3.9           1.3          0.4
# 121          2.8           4.9          2.0
# 66           3.0           4.5          1.5
# 24           3.4           1.9          0.2
# 8            2.9           1.4          0.2
# 126          2.8           4.8          1.8
# 22           3.6           1.0          0.2
# 44           3.8           1.9          0.4
# 97           2.9           4.3          1.3
# 93           2.3           3.3          1.0
# 26           3.4           1.6          0.4
# 137          3.1           5.5          1.8
# 84           3.0           4.5          1.5
# 27           3.5           1.5          0.2
# 127          3.0           4.9          1.8
# 132          2.8           5.6          2.2
# 59           2.7           3.9          1.4
# 18           3.8           1.7          0.3
# 83           2.7           5.1          1.6
# 61           3.0           4.2          1.5
# 92           2.6           4.0          1.2
# 112          3.0           5.5          2.1
# 2            3.2           1.3          0.2
# 141          3.1           5.1          2.3
# 43           3.5           1.6          0.6
# 10           3.7           1.5          0.2
# GaussianNB: Number of mislabeled points out of a total 45 points : 1
# ['Virginica']
# DecisionTreeClassifier: Number of mislabeled points out of a total 45 points : 1
# ['Virginica']

# %%
#selecting data to plot
x = data.iloc[:, 1:4]

y = data.iloc[:, 4:5]

X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.9, random_state=0)

print (X_test)
#gaussian naive basyan
gnb = GaussianNB()
model = gnb.fit(X_train.values, y_train.values.ravel())
y_pred = model.predict(X_test.values)
print(f"GaussianNB: Number of mislabeled points out of a total { X_test.shape[0] } points : {(y_test.values.ravel() != y_pred).sum()}" )

print(model.predict(np.array([[3.2,5.9,2.3]])))

#decussion tree
from sklearn import tree
clf = tree.DecisionTreeClassifier()
model = clf.fit(X_train.values, y_train.values.ravel())
y_pred = model.predict(X_test.values)
print(f"DecisionTreeClassifier: Number of mislabeled points out of a total { X_test.shape[0] } points : {(y_test.values.ravel() != y_pred).sum()}" )
print(model.predict(np.array([[3.2,5.9,2.3]])))
# Out:
#      sepal.width  petal.length  petal.width
# 114          2.8           5.1          2.4
# 62           2.2           4.0          1.0
# 33           4.2           1.4          0.2
# 107          2.9           6.3          1.8
# 7            3.4           1.5          0.2
# 100          3.3           6.0          2.5
# 40           3.5           1.3          0.3
# 86           3.1           4.7          1.5
# 76           2.8           4.8          1.4
# 71           2.8           4.0          1.3
# 134          2.6           5.6          1.4
# 51           3.2           4.5          1.5
# 73           2.8           4.7          1.2
# 54           2.8           4.6          1.5
# 63           2.9           4.7          1.4
# GaussianNB: Number of mislabeled points out of a total 15 points : 0
# ['Virginica']
# DecisionTreeClassifier: Number of mislabeled points out of a total 15 points : 0
# ['Virginica']

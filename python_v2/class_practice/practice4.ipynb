# %% [markdown]
# ### Class practice on 04/06/2024 - Advanced python programming
# ##### Prajwal Luitel (C0927658)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Lecture 4
# #### Python for data transformation

# %%
titanic_df = pd.read_csv("./titanic.csv")
titanic_df.head()
# Out:
#                              name  gender   age class embarked        country  \
# 0             Abbing, Mr. Anthony    male  42.0   3rd        S  United States
# 1       Abbott, Mr. Eugene Joseph    male  13.0   3rd        S  United States
# 2     Abbott, Mr. Rossmore Edward    male  16.0   3rd        S  United States
# 3  Abbott, Mrs. Rhoda Mary 'Rosa'  female  39.0   3rd        S        England
# 4     Abelseth, Miss. Karen Marie  female  16.0   3rd        S         Norway
#
#    ticketno   fare  sibsp  parch survived
# 0    5547.0   7.11    0.0    0.0       no
# 1    2673.0  20.05    0.0    2.0       no
# 2    2673.0  20.05    1.0    1.0       no
# 3    2673.0  20.05    1.0    1.0      yes
# 4  348125.0   7.13    0.0    0.0      yes

# %%
titanic_df.shape
# Out:
# (2207, 11)

# %%
titanic_df.isnull().mean()
# Out:
# name        0.000000
# gender      0.000000
# age         0.000906
# class       0.000000
# embarked    0.000000
# country     0.036701
# ticketno    0.403715
# fare        0.415043
# sibsp       0.407793
# parch       0.407793
# survived    0.000000
# dtype: float64

# %%
titanic_df.describe()
# Out:
#                age      ticketno         fare        sibsp        parch
# count  2205.000000  1.316000e+03  1291.000000  1307.000000  1307.000000
# mean     30.444444  2.842157e+05    33.404760     0.499617     0.385616
# std      12.151764  6.334726e+05    52.227592     1.042273     0.866092
# min       0.166667  2.000000e+00     3.030500     0.000000     0.000000
# 25%      22.000000  1.426225e+04     7.180600     0.000000     0.000000
# 50%      29.000000  1.114265e+05    14.090200     0.000000     0.000000
# 75%      38.000000  3.470770e+05    31.060750     1.000000     0.000000
# max      74.000000  3.101317e+06   512.060700     8.000000     9.000000

# %%
titanic_df.describe(percentiles = [0.01,.1,.2,.3,.5,.6,.7,.8,.9,.99])
# Out:
#                age      ticketno         fare        sibsp        parch
# count  2205.000000  1.316000e+03  1291.000000  1307.000000  1307.000000
# mean     30.444444  2.842157e+05    33.404760     0.499617     0.385616
# std      12.151764  6.334726e+05    52.227592     1.042273     0.866092
# min       0.166667  2.000000e+00     3.030500     0.000000     0.000000
# 1%        2.000000  7.668500e+02     6.150000     0.000000     0.000000
# 10%      18.000000  2.668000e+03     7.140800     0.000000     0.000000
# 20%      21.000000  1.166800e+04     7.170600     0.000000     0.000000
# 30%      24.000000  1.758100e+04     8.010000     0.000000     0.000000
# 50%      29.000000  1.114265e+05    14.090200     0.000000     0.000000
# 60%      32.000000  2.376680e+05    22.070200     0.000000     0.000000
# 70%      36.000000  3.309755e+05    27.140500     1.000000     0.000000
# 80%      40.000000  3.492170e+05    42.080000     1.000000     1.000000
# 90%      46.000000  3.686375e+05    78.050400     1.000000     2.000000
# 99%      63.000000  3.101304e+06   262.070600     5.000000     4.000000
# max      74.000000  3.101317e+06   512.060700     8.000000     9.000000

# %%
titanic_df['age'].quantile(0.01)
# Out:
# 2.0

# %%
titanic_df.drop('ticketno', axis=1).head(1)
# Out:
#                   name gender   age class embarked        country  fare  \
# 0  Abbing, Mr. Anthony   male  42.0   3rd        S  United States  7.11
#
#    sibsp  parch survived
# 0    0.0    0.0       no

# %%
del titanic_df['ticketno']

titanic_df.head()
# Out:
#                              name  gender   age class embarked        country  \
# 0             Abbing, Mr. Anthony    male  42.0   3rd        S  United States
# 1       Abbott, Mr. Eugene Joseph    male  13.0   3rd        S  United States
# 2     Abbott, Mr. Rossmore Edward    male  16.0   3rd        S  United States
# 3  Abbott, Mrs. Rhoda Mary 'Rosa'  female  39.0   3rd        S        England
# 4     Abelseth, Miss. Karen Marie  female  16.0   3rd        S         Norway
#
#     fare  sibsp  parch survived
# 0   7.11    0.0    0.0       no
# 1  20.05    0.0    2.0       no
# 2  20.05    1.0    1.0       no
# 3  20.05    1.0    1.0      yes
# 4   7.13    0.0    0.0      yes

# %% [markdown]
# ### Navigating through a dataframe

# %%
titanic_df.at[0,'age']
# Out:
# 42.0

# %%
titanic_df.at[0,'age'] = 52

titanic_df.at[0,'age']
# Out:
# 52.0

# %%
titanic_df.at[0,'age']
# Out:
# 52.0

# %%
# get index name
titanic_df.index.name

# %%
titanic_df.iloc[1:4]
# Out:
#                              name  gender   age class embarked        country  \
# 1       Abbott, Mr. Eugene Joseph    male  13.0   3rd        S  United States
# 2     Abbott, Mr. Rossmore Edward    male  16.0   3rd        S  United States
# 3  Abbott, Mrs. Rhoda Mary 'Rosa'  female  39.0   3rd        S        England
#
#     fare  sibsp  parch survived
# 1  20.05    0.0    2.0       no
# 2  20.05    1.0    1.0       no
# 3  20.05    1.0    1.0      yes

# %%
titanic_df.loc[1:4]
# Out:
#                              name  gender   age class embarked        country  \
# 1       Abbott, Mr. Eugene Joseph    male  13.0   3rd        S  United States
# 2     Abbott, Mr. Rossmore Edward    male  16.0   3rd        S  United States
# 3  Abbott, Mrs. Rhoda Mary 'Rosa'  female  39.0   3rd        S        England
# 4     Abelseth, Miss. Karen Marie  female  16.0   3rd        S         Norway
#
#     fare  sibsp  parch survived
# 1  20.05    0.0    2.0       no
# 2  20.05    1.0    1.0       no
# 3  20.05    1.0    1.0      yes
# 4   7.13    0.0    0.0      yes

# %% [markdown]
# #### Setting the index

# %%
titanic_df.set_index(titanic_df['name'], inplace=True)
titanic_df.index.name
# Out:
# 'name'

# %%
titanic_df.loc['Abbott, Mr. Eugene Joseph']
# Out:
# name        Abbott, Mr. Eugene Joseph
# gender                           male
# age                              13.0
# class                             3rd
# embarked                            S
# country                 United States
# fare                            20.05
# sibsp                             0.0
# parch                             2.0
# survived                           no
# Name: Abbott, Mr. Eugene Joseph, dtype: object

# %%
# doesn't work as index is not a number
titanic_df.iloc['Abbott, Mr. Eugene Joseph']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 titanic_df.iloc['Abbott, Mr. Eugene Joseph']
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexing.py:1711, in _iLocIndexer._getitem_axis(self, key, axis)
#    1709 key = item_from_zerodim(key)
#    1710 if not is_integer(key):
# -> 1711     raise TypeError("Cannot index by location index with a non-integer key")
#    1713 # validate the location
#    1714 self._validate_integer(key, axis)
#
# TypeError: Cannot index by location index with a non-integer key

# %%
titanic_df.loc[1:4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 titanic_df.loc[1:4]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexing.py:1373, in _LocIndexer._getitem_axis(self, key, axis)
#    1371 if isinstance(key, slice):
#    1372     self._validate_key(key, axis)
# -> 1373     return self._get_slice_axis(key, axis=axis)
#    1374 elif com.is_bool_indexer(key):
#    1375     return self._getbool_axis(key, axis=axis)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexing.py:1405, in _LocIndexer._get_slice_axis(self, slice_obj, axis)
#    1402     return obj.copy(deep=False)
#    1404 labels = obj._get_axis(axis)
# -> 1405 indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop, slice_obj.step)
#    1407 if isinstance(indexer, slice):
#    1408     return self.obj._slice(indexer, axis=axis)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:6602, in Index.slice_indexer(self, start, end, step)
#    6558 def slice_indexer(
#    6559     self,
#    6560     start: Hashable | None = None,
#    6561     end: Hashable | None = None,
#    6562     step: int | None = None,
#    6563 ) -> slice:
#    6564     """
#    6565     Compute the slice indexer for input labels and step.
#    6566
#    (...)
#    6600     slice(1, 3, None)
#    6601     """
# -> 6602     start_slice, end_slice = self.slice_locs(start, end, step=step)
#    6604     # return a slice
#    6605     if not is_scalar(start_slice):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:6819, in Index.slice_locs(self, start, end, step)
#    6817 start_slice = None
#    6818 if start is not None:
# -> 6819     start_slice = self.get_slice_bound(start, "left")
#    6820 if start_slice is None:
#    6821     start_slice = 0
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:6734, in Index.get_slice_bound(self, label, side)
#    6730 original_label = label
#    6732 # For datetime indices label may be a string that has to be converted
#    6733 # to datetime boundary according to its resolution.
# -> 6734 label = self._maybe_cast_slice_bound(label, side)
#    6736 # we need to look up the label
#    6737 try:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:6667, in Index._maybe_cast_slice_bound(self, label, side)
#    6665 # reject them, if index does not contain label
#    6666 if (is_float(label) or is_integer(label)) and label not in self:
# -> 6667     self._raise_invalid_indexer("slice", label)
#    6669 return label
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:4306, in Index._raise_invalid_indexer(self, form, key, reraise)
#    4304 if reraise is not lib.no_default:
#    4305     raise TypeError(msg) from reraise
# -> 4306 raise TypeError(msg)
#
# TypeError: cannot do slice indexing on Index with these indexers [1] of type int

# %%
titanic_df.iloc[1:4]
# Out:
#                                                           name  gender   age  \
# name
# Abbott, Mr. Eugene Joseph            Abbott, Mr. Eugene Joseph    male  13.0
# Abbott, Mr. Rossmore Edward        Abbott, Mr. Rossmore Edward    male  16.0
# Abbott, Mrs. Rhoda Mary 'Rosa'  Abbott, Mrs. Rhoda Mary 'Rosa'  female  39.0
#
#                                class embarked        country   fare  sibsp  \
# name
# Abbott, Mr. Eugene Joseph        3rd        S  United States  20.05    0.0
# Abbott, Mr. Rossmore Edward      3rd        S  United States  20.05    1.0
# Abbott, Mrs. Rhoda Mary 'Rosa'   3rd        S        England  20.05    1.0
#
#                                 parch survived
# name
# Abbott, Mr. Eugene Joseph         2.0       no
# Abbott, Mr. Rossmore Edward       1.0       no
# Abbott, Mrs. Rhoda Mary 'Rosa'    1.0      yes

# %%
titanic_df.reset_index(drop=True, inplace=True)
titanic_df.head()
# Out:
#                              name  gender   age class embarked        country  \
# 0             Abbing, Mr. Anthony    male  52.0   3rd        S  United States
# 1       Abbott, Mr. Eugene Joseph    male  13.0   3rd        S  United States
# 2     Abbott, Mr. Rossmore Edward    male  16.0   3rd        S  United States
# 3  Abbott, Mrs. Rhoda Mary 'Rosa'  female  39.0   3rd        S        England
# 4     Abelseth, Miss. Karen Marie  female  16.0   3rd        S         Norway
#
#     fare  sibsp  parch survived
# 0   7.11    0.0    0.0       no
# 1  20.05    0.0    2.0       no
# 2  20.05    1.0    1.0       no
# 3  20.05    1.0    1.0      yes
# 4   7.13    0.0    0.0      yes

# %% [markdown]
# #### Selecting rows based on conditions

# %%
titanic_df[titanic_df['gender']=='female'].shape
# Out:
# (489, 10)

# %%
# create a sub table
female_df = titanic_df[titanic_df['gender']=='female']
female_df.shape
# Out:
# (489, 10)

# %%
# Create a sub-table with multiple conditions using logical and
female_more_than_fifty = titanic_df.query("gender=='female' and age > 50 ")
female_more_than_fifty.shape
# Out:
# (36, 10)

# %%
# Creating sub table with multiple conditions using logical or
female_or_more_than_fifty = titanic_df.query("gender == 'female' or age >50")
female_or_more_than_fifty.shape
# Out:
# (586, 10)

# %%
# Creating sub table with multiple conditions using logical or and logical and
female_greater_fifty_male_less_twenty = titanic_df.query(f"(gender =='female' and age>50) or (gender=='male' and age<20) ")
female_greater_fifty_male_less_twenty.shape
# Out:
# (244, 10)

# %% [markdown]
# #### Adjusting dataframe

# %%
titanic_df['gender'].replace(['female','male'], ['W','M']).head(5)
# Out:
# 0    M
# 1    M
# 2    M
# 3    W
# 4    W
# Name: gender, dtype: object

# %%
# creting new column
titanic_df['sex'] = titanic_df['gender'].replace(['female', 'male'],[1,0])
titanic_df['sex'].value_counts()
# Out:
# sex
# 0    1718
# 1     489
# Name: count, dtype: int64

# %%
titanic_df['gender'].value_counts(dropna=False)
# Out:
# gender
# male      1718
# female     489
# Name: count, dtype: int64

# %%
titanic_df['survived_ind'] = titanic_df['survived'].replace(['yes', 'no'], [1,0])
titanic_df.survived_ind.value_counts(dropna=False)
# Out:
# survived_ind
# 0    1496
# 1     711
# Name: count, dtype: int64

# %%
titanic_df.head()
# Out:
#                              name  gender   age class embarked        country  \
# 0             Abbing, Mr. Anthony    male  52.0   3rd        S  United States
# 1       Abbott, Mr. Eugene Joseph    male  13.0   3rd        S  United States
# 2     Abbott, Mr. Rossmore Edward    male  16.0   3rd        S  United States
# 3  Abbott, Mrs. Rhoda Mary 'Rosa'  female  39.0   3rd        S        England
# 4     Abelseth, Miss. Karen Marie  female  16.0   3rd        S         Norway
#
#     fare  sibsp  parch survived  sex  survived_ind
# 0   7.11    0.0    0.0       no    0             0
# 1  20.05    0.0    2.0       no    0             0
# 2  20.05    1.0    1.0       no    0             0
# 3  20.05    1.0    1.0      yes    1             1
# 4   7.13    0.0    0.0      yes    1             1

# %% [markdown]
# #### Crosstabs

# %%
pd.crosstab(titanic_df['sex'], titanic_df['gender'], margins=True, margins_name="total")
# Out:
# gender  female  male  total
# sex
# 0            0  1718   1718
# 1          489     0    489
# total      489  1718   2207

# %%
crosstab = pd.crosstab(titanic_df['survived'], titanic_df['gender'], margins=True, margins_name="total")
crosstab
# Out:
# gender    female  male  total
# survived
# no           130  1366   1496
# yes          359   352    711
# total        489  1718   2207

# %%
crosstab = pd.crosstab(titanic_df['survived'], [titanic_df['gender'], titanic_df['class']], margins=True, margins_name="total")
crosstab
# Out:
# gender   female                                             male            \
# class       1st  2nd  3rd restaurant staff victualling crew  1st  2nd  3rd
# survived
# no            5   12  110                0                3  118  154  418
# yes         139   94  106                2               18   62   24   75
# total       144  106  216                2               21  180  178  493
#
# gender                                                                total
# class    deck crew engineering crew restaurant staff victualling crew
# survived
# no              23              253               66              334  1496
# yes             43               71                1               76   711
# total           66              324               67              410  2207

# %% [markdown]
# #### Renaming a column

# %%
titanic_df.rename(columns={'class':'passenger_class'}, inplace=True)
titanic_df.head(1)
# Out:
#                   name gender   age passenger_class embarked        country  \
# 0  Abbing, Mr. Anthony   male  52.0             3rd        S  United States
#
#    fare  sibsp  parch survived  sex  survived_ind
# 0  7.11    0.0    0.0       no    0             0

# %% [markdown]
# #### Counting missing values

# %%
titanic_df[titanic_df['age'].isnull()].shape[0]
# Out:
# 2

# %%
type(titanic_df[titanic_df['age'].notna()].shape)
# Out:
# tuple

# %%
titanic_df[titanic_df['age'].notna()].shape
# Out:
# (2205, 12)

# %%
titanic_df[titanic_df['age'].isnull()==False].shape[0]
# Out:
# 2205

# %%
titanic_df.query("age.isnull()")
# Out:
#                        name gender  age passenger_class embarked   country  \
# 439  Gheorgheff, Mr. Stanio   male  NaN             3rd        C  Bulgaria
# 677     Kraeff, Mr. Theodor   male  NaN             3rd        C  Bulgaria
#
#        fare  sibsp  parch survived  sex  survived_ind
# 439  7.1711    0.0    0.0       no    0             0
# 677  7.1711    0.0    0.0       no    0             0

# %% [markdown]
# #### Unique value

# %%
titanic_df['country'].nunique()
# Out:
# 48

# %%
titanic_df['country'].unique()
# Out:
# array(['United States', 'England', 'Norway', 'France', 'Lebanon',
#        'Finland', 'Sweden', 'Argentina', 'Canada', 'Denmark',
#        'Northern Ireland', 'Bulgaria', 'Switzerland', 'Channel Islands',
#        'Bosnia', 'Hungary', nan, 'Ireland', 'Italy', 'India', 'Wales',
#        'South Africa', 'Croatia (Modern)', 'Scotland', 'Siam', 'Uruguay',
#        'Belgium', 'Poland', 'Australia', 'Peru', 'Spain', 'Egypt',
#        'Japan', 'Syria', 'Russia', 'Slovenia', 'Greece', 'Turkey',
#        'China/Hong Kong', 'Austria', 'Latvia', 'Yugoslavia',
#        'Slovakia (Modern day)', 'Germany', 'Croatia', 'Cuba',
#        'Netherlands', 'Mexico', 'Guyana'], dtype=object)

# %%
titanic_df['country'].value_counts(dropna=False)
# Out:
# country
# England                  1125
# United States             264
# Ireland                   137
# Sweden                    105
# NaN                        81
# Lebanon                    71
# Finland                    54
# Scotland                   36
# Canada                     34
# France                     26
# Norway                     26
# Belgium                    22
# Northern Ireland           21
# Wales                      20
# Bulgaria                   19
# Switzerland                18
# Channel Islands            17
# Croatia (Modern)           12
# Croatia                    11
# Italy                      11
# Spain                       9
# India                       8
# Hungary                     7
# Denmark                     7
# Argentina                   7
# South Africa                6
# Germany                     6
# Turkey                      6
# Australia                   5
# Slovenia                    4
# Bosnia                      4
# Poland                      3
# Austria                     3
# Netherlands                 2
# Greece                      2
# Siam                        2
# Russia                      2
# Peru                        2
# Uruguay                     2
# Syria                       1
# China/Hong Kong             1
# Japan                       1
# Latvia                      1
# Yugoslavia                  1
# Slovakia (Modern day)       1
# Egypt                       1
# Cuba                        1
# Mexico                      1
# Guyana                      1
# Name: count, dtype: int64

# %%
crosstab= pd.crosstab( titanic_df['country'],titanic_df['survived_ind'], margins=True, margins_name='total')
crosstab
# Out:
# survived_ind              0    1  total
# country
# Argentina                 7    0      7
# Australia                 5    0      5
# Austria                   2    1      3
# Belgium                  17    5     22
# Bosnia                    4    0      4
# Bulgaria                 19    0     19
# Canada                   19   15     34
# Channel Islands           9    8     17
# China/Hong Kong           0    1      1
# Croatia                  11    0     11
# Croatia (Modern)         10    2     12
# Cuba                      1    0      1
# Denmark                   6    1      7
# Egypt                     0    1      1
# England                 831  294   1125
# Finland                  37   17     54
# France                   11   15     26
# Germany                   3    3      6
# Greece                    2    0      2
# Guyana                    1    0      1
# Hungary                   6    1      7
# India                     2    6      8
# Ireland                  90   47    137
# Italy                     9    2     11
# Japan                     0    1      1
# Latvia                    1    0      1
# Lebanon                  40   31     71
# Mexico                    1    0      1
# Netherlands               2    0      2
# Northern Ireland         17    4     21
# Norway                   19    7     26
# Peru                      1    1      2
# Poland                    1    2      3
# Russia                    1    1      2
# Scotland                 28    8     36
# Siam                      0    2      2
# Slovakia (Modern day)     1    0      1
# Slovenia                  3    1      4
# South Africa              4    2      6
# Spain                     2    7      9
# Sweden                   77   28    105
# Switzerland               7   11     18
# Syria                     0    1      1
# Turkey                    4    2      6
# United States           112  152    264
# Uruguay                   2    0      2
# Wales                    17    3     20
# Yugoslavia                1    0      1
# total                  1443  683   2126

# %%
# For each row, add a column which is percentage of survival
crosstab['percentage'] = (crosstab[1]/crosstab['total'])*100
crosstab
# Out:
# survived_ind              0    1  total  percentage
# country
# Argentina                 7    0      7    0.000000
# Australia                 5    0      5    0.000000
# Austria                   2    1      3   33.333333
# Belgium                  17    5     22   22.727273
# Bosnia                    4    0      4    0.000000
# Bulgaria                 19    0     19    0.000000
# Canada                   19   15     34   44.117647
# Channel Islands           9    8     17   47.058824
# China/Hong Kong           0    1      1  100.000000
# Croatia                  11    0     11    0.000000
# Croatia (Modern)         10    2     12   16.666667
# Cuba                      1    0      1    0.000000
# Denmark                   6    1      7   14.285714
# Egypt                     0    1      1  100.000000
# England                 831  294   1125   26.133333
# Finland                  37   17     54   31.481481
# France                   11   15     26   57.692308
# Germany                   3    3      6   50.000000
# Greece                    2    0      2    0.000000
# Guyana                    1    0      1    0.000000
# Hungary                   6    1      7   14.285714
# India                     2    6      8   75.000000
# Ireland                  90   47    137   34.306569
# Italy                     9    2     11   18.181818
# Japan                     0    1      1  100.000000
# Latvia                    1    0      1    0.000000
# Lebanon                  40   31     71   43.661972
# Mexico                    1    0      1    0.000000
# Netherlands               2    0      2    0.000000
# Northern Ireland         17    4     21   19.047619
# Norway                   19    7     26   26.923077
# Peru                      1    1      2   50.000000
# Poland                    1    2      3   66.666667
# Russia                    1    1      2   50.000000
# Scotland                 28    8     36   22.222222
# Siam                      0    2      2  100.000000
# Slovakia (Modern day)     1    0      1    0.000000
# Slovenia                  3    1      4   25.000000
# South Africa              4    2      6   33.333333
# Spain                     2    7      9   77.777778
# Sweden                   77   28    105   26.666667
# Switzerland               7   11     18   61.111111
# Syria                     0    1      1  100.000000
# Turkey                    4    2      6   33.333333
# United States           112  152    264   57.575758
# Uruguay                   2    0      2    0.000000
# Wales                    17    3     20   15.000000
# Yugoslavia                1    0      1    0.000000
# total                  1443  683   2126   32.126058

# %%
crosstab.sort_values(['total', 'percentage'], ascending=False)
# Out:
# survived_ind              0    1  total  percentage
# country
# total                  1443  683   2126   32.126058
# England                 831  294   1125   26.133333
# United States           112  152    264   57.575758
# Ireland                  90   47    137   34.306569
# Sweden                   77   28    105   26.666667
# Lebanon                  40   31     71   43.661972
# Finland                  37   17     54   31.481481
# Scotland                 28    8     36   22.222222
# Canada                   19   15     34   44.117647
# France                   11   15     26   57.692308
# Norway                   19    7     26   26.923077
# Belgium                  17    5     22   22.727273
# Northern Ireland         17    4     21   19.047619
# Wales                    17    3     20   15.000000
# Bulgaria                 19    0     19    0.000000
# Switzerland               7   11     18   61.111111
# Channel Islands           9    8     17   47.058824
# Croatia (Modern)         10    2     12   16.666667
# Italy                     9    2     11   18.181818
# Croatia                  11    0     11    0.000000
# Spain                     2    7      9   77.777778
# India                     2    6      8   75.000000
# Denmark                   6    1      7   14.285714
# Hungary                   6    1      7   14.285714
# Argentina                 7    0      7    0.000000
# Germany                   3    3      6   50.000000
# South Africa              4    2      6   33.333333
# Turkey                    4    2      6   33.333333
# Australia                 5    0      5    0.000000
# Slovenia                  3    1      4   25.000000
# Bosnia                    4    0      4    0.000000
# Poland                    1    2      3   66.666667
# Austria                   2    1      3   33.333333
# Siam                      0    2      2  100.000000
# Peru                      1    1      2   50.000000
# Russia                    1    1      2   50.000000
# Greece                    2    0      2    0.000000
# Netherlands               2    0      2    0.000000
# Uruguay                   2    0      2    0.000000
# China/Hong Kong           0    1      1  100.000000
# Egypt                     0    1      1  100.000000
# Japan                     0    1      1  100.000000
# Syria                     0    1      1  100.000000
# Cuba                      1    0      1    0.000000
# Guyana                    1    0      1    0.000000
# Latvia                    1    0      1    0.000000
# Mexico                    1    0      1    0.000000
# Slovakia (Modern day)     1    0      1    0.000000
# Yugoslavia                1    0      1    0.000000
